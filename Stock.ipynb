# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as mse
import seaborn as sns

# %%
stock = pd.read_csv('Data.csv');

# %%
clean = stock[(stock['Available to Deploy'] !=0)&(stock['Reorder Point (Hl)']!=0)]

# %%
clean
# Out:
#      Supply Site Code    SKU Location Code Location Type  MinDOC (Hl)  \
# 0             PL-1505  85021       PL-1505           DEP      19218.6
# 1             PL-1505  85023       PL-1505           DEP       3228.3
# 2             PL-1505  85023       PL-1831           DEP        139.5
# 3             PL-1505  85023       PL-1837           DEP         57.7
# 4             PL-1505  85023       PL-1835           DEP        223.7
# ...               ...    ...           ...           ...          ...
# 3723          PL-1926  92105       PL-1718           DEP        279.5
# 3724          PL-1926  92105       PL-9100          DIST       1062.3
# 3725          PL-1926  92105       PL-9020          DIST       1231.0
# 3726          PL-1926  92105       PL-9120          DIST        279.6
# 3727          PL-1926  92105       PL-1927          DIST        125.5
#
#       Reorder Point (Hl)  MaxDOC (Hl)  Closing Stock  Distributor Orders  \
# 0                70565.6     157453.7           0.00                   0
# 1                40347.9      54904.3           0.00                   0
# 2                  532.3       1231.8           0.00                   0
# 3                  182.3        408.9         321.82                   0
# 4                  969.4       2430.6        2279.63                   0
# ...                  ...          ...            ...                 ...
# 3723               887.4       2503.3        5217.58                   0
# 3724              3541.1       6019.9         860.89                   0
# 3725              4103.3       6975.6        2980.67                   0
# 3726               932.1       1584.6        2572.79                   0
# 3727               394.2       1150.9        1285.95                   0
#
#       Current CS/MIN  Current CS/ROP  Current CS/MAX  Available to Deploy  \
# 0              0.000           0.000           0.000              16372.2
# 1              0.000           0.000           0.000              24081.3
# 2              0.000           0.000           0.000              24081.3
# 3              5.580           1.765           0.787              24081.3
# 4             10.188           2.352           0.938              24081.3
# ...              ...             ...             ...                  ...
# 3723          18.671           5.880           2.084              69307.9
# 3724           0.810           0.243           0.143              69307.9
# 3725           2.421           0.726           0.427              69307.9
# 3726           9.201           2.760           1.624              69307.9
# 3727          10.245           3.262           1.117              69307.9
#
#       Scenario
# 0            4
# 1            3
# 2            3
# 3            3
# 4            3
# ...        ...
# 3723         3
# 3724         3
# 3725         3
# 3726         3
# 3727         3
#
# [1964 rows x 14 columns]
